# %% [markdown]
# # 🧠 Conversational Agent with Memory
#
# **Build an AI agent that remembers you!**
#
# This notebook demonstrates Praval's memory system by creating a conversational agent that:
# - 💾 **Remembers** previous conversations
# - 🎯 **Asks relevant** follow-up questions based on what it knows
# - 🤝 **Responds personally** using knowledge from earlier interactions
# - 🔍 **Searches semantically** across all stored memories
#
# **No setup required!** The memory system uses ChromaDB embedded storage - everything works immediately.

# %% [markdown]
# ## 📦 Setup & Imports

# %%
import sys
import os
from pathlib import Path

# Add parent directory to path for imports
sys.path.insert(0, str(Path.cwd().parent / 'src'))

# Load environment variables
from dotenv import load_dotenv
load_dotenv(Path.cwd().parent / '.env')

from praval import agent, chat, start_agents

print("✅ Imports successful!")
print("✅ Memory system initialized (ChromaDB embedded)")
print("\n🎉 This agent will remember our conversations!")
# Out:
# ✅ Imports successful!
# ✅ Memory system initialized (ChromaDB embedded)
#
# 🎉 This agent will remember our conversations!

# %% [markdown]
# ## 🤖 Create Memory-Enabled Agent
#
# Let's create a conversational assistant that uses memory to provide personalized responses.

# %%
@agent("conversational_assistant", 
       memory=True,  # Enable memory!
       responds_to=["user_message"])
def memory_assistant(spore):
    """
    I'm a conversational assistant with memory.
    I remember our past conversations and use that context 
    to provide personalized, relevant responses.
    """
    user_input = spore.knowledge.get("message")
    
    print(f"\n💬 You: {user_input}")
    print("\n🔍 Searching memories...")
    
    # 1. RECALL relevant past conversations
    past_context = memory_assistant.recall(user_input, limit=5)
    
    # 2. Build context string from memories
    if past_context:
        print(f"✅ Found {len(past_context)} relevant memories!\n")
        context_summary = "What I remember about you:\n"
        for i, memory in enumerate(past_context, 1):
            context_summary += f"{i}. {memory.content[:100]}...\n"
            print(f"   📝 Memory {i}: {memory.content[:80]}...")
    else:
        print("🆕 This is our first conversation!\n")
        context_summary = "This is our first conversation!"
    
    print("\n🤔 Generating response...")
    
    # 3. GENERATE response using memory context
    response = chat(f"""
    You are a helpful conversational assistant with memory.
    
    {context_summary}
    
    User's current message: {user_input}
    
    Instructions:
    - Reference relevant memories in your response
    - Ask thoughtful follow-up questions based on what you know
    - Be warm and personalized
    - Show that you remember the conversation history
    - Keep responses concise (2-3 sentences)
    """)
    
    # 4. REMEMBER this interaction
    memory_text = f"User said: {user_input}. I responded about: {response[:100]}"
    memory_assistant.remember(memory_text, importance=0.7)
    
    print(f"\n🤖 Assistant: {response}")
    print(f"\n💾 Stored this interaction in memory")
    print("="*70)
    
    return {"response": response, "memories_used": len(past_context)}

print("✅ Agent created successfully!")
print("\n🎯 The agent has three memory superpowers:")
print("   1. 🔍 Recalls relevant past conversations")
print("   2. 🧠 Uses that context to respond personally")
print("   3. 💾 Stores new interactions for future use")
# Out:
# Legacy collection migration not needed or failed: Collection [praval_memories_conversational_assistant] does not exists
# Memory system initialized for agent conversational_assistant
# ✅ Agent created successfully!
#
# 🎯 The agent has three memory superpowers:
#    1. 🔍 Recalls relevant past conversations
#    2. 🧠 Uses that context to respond personally
#    3. 💾 Stores new interactions for future use

# %% [markdown]
# ## 💬 Let's Have Conversations!
#
# Watch how the agent remembers context and builds on previous conversations.
#
# ### Helper Function

# %%
def talk(message):
    """Helper function to make conversations easy"""
    result = start_agents(
        memory_assistant,
        initial_data={
            "type": "user_message",
            "message": message
        }
    )
    return result

print("✅ Helper function ready!")
print("\nUse: talk('your message here')")
# Out:
# ✅ Helper function ready!
#
# Use: talk('your message here')

# %% [markdown]
# ### 🎬 Conversation 1: Introduction
#
# Let's start by introducing ourselves. The agent will remember this!

# %%
talk("Hi! I'm learning Python for web development.")
# Out:
# 💬 You: Hi! I'm learning Python for web development.
#
# 🔍 Searching memories...
# '352ba969-3829-43ce-8713-e95e9d98ad05'
# 🆕 This is our first conversation!
#
#
# 🤔 Generating response...
#
# 🤖 Assistant: Hi there! That's awesome that you're diving into Python for web development. Remembering our first chat, I see you're eager to learn new skills. How's your Python journey going so far? Any specific projects or goals in mind?
#
# 💾 Stored this interaction in memory
# ======================================================================

# %% [markdown]
# ### 💡 Conversation 2: Building on Context
#
# Now let's ask for advice. Watch how the agent remembers we're learning Python for web dev!

# %%
talk("What should I learn next?")
# Out:
# 💬 You: What should I learn next?
#
# 🔍 Searching memories...
# '1d35ca64-f053-4f63-9c22-2128dbe1dd4a'
# ✅ Found 2 relevant memories!
#
#    📝 Memory 1: User: {'type': 'user_message', 'message': "Hi! I'm learning Python for web devel...
#    📝 Memory 2: User said: Hi! I'm learning Python for web development.. I responded about: Hi t...
#
# 🤔 Generating response...
#
# 🤖 Assistant: Great to see your enthusiasm for learning! Based on our previous conversation about Python, you might consider diving into web frameworks like Django or Flask to enhance your web development skills. Have you thought about which area of web development you're most interested in exploring next?
#
# 💾 Stored this interaction in memory
# ======================================================================

# %% [markdown]
# ### 🎯 Conversation 3: Adding More Context
#
# Let's mention a specific interest. The agent will combine this with previous memories.

# %%
talk("I'm particularly interested in building REST APIs.")
# Out:
# 💬 You: I'm particularly interested in building REST APIs.
#
# 🔍 Searching memories...
# '64d22a7d-2956-4844-9982-2de50a8190b9'
# ✅ Found 4 relevant memories!
#
#    📝 Memory 1: User: {'type': 'user_message', 'message': 'What should I learn next?'}
# Agent: {'...
#    📝 Memory 2: User said: Hi! I'm learning Python for web development.. I responded about: Hi t...
#    📝 Memory 3: User: {'type': 'user_message', 'message': "Hi! I'm learning Python for web devel...
#    📝 Memory 4: User said: What should I learn next?. I responded about: Great to see your enthu...
#
# 🤔 Generating response...
#
# 🤖 Assistant: That's fantastic to hear about your interest in building REST APIs! Given your focus, diving into frameworks like Django Rest Framework or Flask-RESTful could be a great next step. Have you thought about a specific project where you could apply these API-building skills?
#
# 💾 Stored this interaction in memory
# ======================================================================

# %% [markdown]
# ### 🚀 Conversation 4: Technical Question
#
# Now ask a technical question. The agent should recall your entire learning journey!

# %%
talk("Which Python web framework should I use?")
# Out:
# 💬 You: Which Python web framework should I use?
#
# 🔍 Searching memories...
# 'a5965cc5-c4ac-424c-8649-c9c0693a77d9'
# ✅ Found 5 relevant memories!
#
#    📝 Memory 1: User: {'type': 'user_message', 'message': 'What should I learn next?'}
# Agent: {'...
#    📝 Memory 2: User: {'type': 'user_message', 'message': "Hi! I'm learning Python for web devel...
#    📝 Memory 3: User: {'type': 'user_message', 'message': "I'm particularly interested in buildi...
#    📝 Memory 4: User said: What should I learn next?. I responded about: Great to see your enthu...
#    📝 Memory 5: User said: Hi! I'm learning Python for web development.. I responded about: Hi t...
#
# 🤔 Generating response...
#
# 🤖 Assistant: Given your interest in building REST APIs, Django Rest Framework could be a great choice for you due to its robust features for API development. Have you considered exploring Django Rest Framework to see how it aligns with your goals for building APIs?
#
# 💾 Stored this interaction in memory
# ======================================================================

# %% [markdown]
# ### 🔮 Conversation 5: Memory Test
#
# Let's explicitly ask the agent what it remembers!

# %%
talk("Tell me what you remember about me and my learning goals.")
# Out:
# 💬 You: Tell me what you remember about me and my learning goals.
#
# 🔍 Searching memories...
# '96d2683a-d9d0-4011-910d-b20759b55fe9'
# ✅ Found 5 relevant memories!
#
#    📝 Memory 1: User said: What should I learn next?. I responded about: Great to see your enthu...
#    📝 Memory 2: User: {'type': 'user_message', 'message': "Hi! I'm learning Python for web devel...
#    📝 Memory 3: User: {'type': 'user_message', 'message': 'What should I learn next?'}
# Agent: {'...
#    📝 Memory 4: User said: Hi! I'm learning Python for web development.. I responded about: Hi t...
#    📝 Memory 5: User: {'type': 'user_message', 'message': "I'm particularly interested in buildi...
#
# 🤔 Generating response...
#
# 🤖 Assistant: I remember your interest in learning Python for web development, specifically focusing on building REST APIs. You've shown enthusiasm for exploring new skills and frameworks. How are you feeling about your progress in achieving your learning goals so far?
#
# 💾 Stored this interaction in memory
# ======================================================================

# %% [markdown]
# ## 🎮 Your Turn!
#
# Try your own conversations below. The agent will remember everything!

# %%
# Try your own message!
talk("What does an ORM do in Django? How do I use one effectively?")
# Out:
# 💬 You: What does an ORM do in Django? How do I use one effectively?
#
# 🔍 Searching memories...
# '34933ef0-61f6-46e8-854f-d19223faa642'
# ✅ Found 5 relevant memories!
#
#    📝 Memory 1: User: {'type': 'user_message', 'message': 'Which Python web framework should I u...
#    📝 Memory 2: User said: Which Python web framework should I use?. I responded about: Given yo...
#    📝 Memory 3: User: {'type': 'user_message', 'message': "I'm particularly interested in buildi...
#    📝 Memory 4: User: {'type': 'user_message', 'message': 'What should I learn next?'}
# Agent: {'...
#    📝 Memory 5: User: {'type': 'user_message', 'message': 'Tell me what you remember about me an...
#
# 🤔 Generating response...
#
# 🤖 Assistant: Great question! An ORM (Object-Relational Mapping) in Django allows you to interact with your database using Python objects instead of writing SQL queries directly. To use it effectively, start by defining your models in Django, then utilize the ORM methods like filter(), save(), and create() for database operations. Have you had a chance to work with Django's ORM yet, or are you looking to explore it further?
#
# 💾 Stored this interaction in memory
# ======================================================================

# %%
# Another conversation
talk("Are there similar ones in other frameworks such as FastAPI?")
# Out:
# 💬 You: Are there similar ones in other frameworks such as FastAPI?
#
# 🔍 Searching memories...
# '82a94069-a826-4cc9-84b9-a15440bf2e0d'
# ✅ Found 5 relevant memories!
#
#    📝 Memory 1: User said: I'm particularly interested in building REST APIs.. I responded about...
#    📝 Memory 2: User said: Which Python web framework should I use?. I responded about: Given yo...
#    📝 Memory 3: User: {'type': 'user_message', 'message': 'Which Python web framework should I u...
#    📝 Memory 4: User: {'type': 'user_message', 'message': "I'm particularly interested in buildi...
#    📝 Memory 5: User: {'type': 'user_message', 'message': 'What should I learn next?'}
# Agent: {'...
#
# 🤔 Generating response...
#
# 🤖 Assistant: Absolutely! FastAPI, a modern web framework for building APIs with Python, also provides similar features for creating RESTful APIs like Django Rest Framework. Have you had a chance to explore FastAPI or compare its approach to building APIs with Django Rest Framework?
#
# 💾 Stored this interaction in memory
# ======================================================================

# %%
# Keep going!
talk("What have you learned about me so far? Can you summarize, from our conversation? Can you give me something really interesting and zen based on what you know?")
# Out:
# 💬 You: What have you learned about me so far? Can you summarize, from our conversation? Can you give me something really interesting and zen based on what you know?
#
# 🔍 Searching memories...
# 'c07b03f9-6757-4a83-808e-1a41508bbf21'
# ✅ Found 5 relevant memories!
#
#    📝 Memory 1: User said: The agent keeps learning about you.... I responded about: It's great ...
#    📝 Memory 2: User said: What have you learned about me so far? Can you summarize, from our co...
#    📝 Memory 3: User: {'type': 'user_message', 'message': 'What have you learned about me so far...
#    📝 Memory 4: User said: What should I learn next?. I responded about: Great to see your enthu...
#    📝 Memory 5: User said: Tell me what you remember about me and my learning goals.. I responde...
#
# 🤔 Generating response...
#
# 🤖 Assistant: From our conversations, I've learned about your journey in learning Python for web development and your keen interest in building REST APIs. Your enthusiasm for exploring new skills and frameworks is inspiring. Remember, "In the world of coding, every line written is a step closer to turning imagination into reality." How can I assist you further on your coding journey today?
#
# 💾 Stored this interaction in memory
# ======================================================================

# %% [markdown]
# ## 🔍 Memory Inspection
#
# Let's peek inside the agent's memory to see what it has stored!

# %% [markdown]
# ### View All Stored Memories

# %%
# Retrieve all memories (empty query returns all)
all_memories = memory_assistant.recall("", limit=50)

print(f"📚 Total memories stored: {len(all_memories)}")
print("\n" + "="*70)

for i, mem in enumerate(all_memories, 1):
    print(f"\n{i}. {mem.content}")
    print(f"   ⏰ Created: {mem.created_at.strftime('%Y-%m-%d %H:%M:%S')}")
    print(f"   ⭐ Importance: {mem.importance}")
    print(f"   👁️  Accessed: {mem.access_count} times")
# Out:
# 📚 Total memories stored: 0
#
# ======================================================================

# %% [markdown]
# ### Semantic Search
#
# Search memories by meaning, not just keywords!

# %%
# Search for specific topics
search_query = "learning programming"

print(f"🔎 Searching for: '{search_query}'")
print("="*70)

results = memory_assistant.recall(search_query, limit=5)

print(f"\n✅ Found {len(results)} relevant memories:\n")

for i, result in enumerate(results, 1):
    print(f"{i}. {result.content}")
    print(f"   📊 Relevance: {result.importance}")
    print()

# %% [markdown]
# ### Try Your Own Searches

# %%
# Search for something specific
custom_search = "web development"  # Change this!

results = memory_assistant.recall(custom_search, limit=5)

print(f"🔎 Searching for: '{custom_search}'")
print(f"✅ Found {len(results)} memories\n")

for i, result in enumerate(results, 1):
    print(f"{i}. {result.content[:100]}...")

# %% [markdown]
# ## 📊 Memory Statistics

# %%
# Get conversation context
try:
    context_turns = memory_assistant.get_conversation_context(turns=20)
    
    print("📈 Memory System Statistics")
    print("="*70)
    print(f"💬 Total conversation turns: {len(context_turns)}")
    print(f"📚 Total memories: {len(all_memories)}")
    print(f"⭐ Average importance: {sum(m.importance for m in all_memories) / len(all_memories):.2f}")
    print(f"👁️  Total memory accesses: {sum(m.access_count for m in all_memories)}")
    
    print("\n🎯 Most accessed memories:")
    sorted_by_access = sorted(all_memories, key=lambda m: m.access_count, reverse=True)[:3]
    for i, mem in enumerate(sorted_by_access, 1):
        print(f"  {i}. ({mem.access_count}x) {mem.content[:60]}...")
        
except Exception as e:
    print(f"Note: Some memory statistics may not be available: {e}")
    print(f"\nBasic stats:")
    print(f"📚 Total memories: {len(all_memories)}")

# %% [markdown]
# ## 🎓 What We Learned
#
# ### Memory Capabilities Demonstrated:
#
# 1. **✅ Automatic Storage**
#    - Agent automatically stores each interaction
#    - No manual memory management needed
#
# 2. **✅ Semantic Search**
#    - Search by meaning, not just keywords
#    - Finds conceptually related memories
#
# 3. **✅ Context Awareness**
#    - Agent references previous conversations
#    - Builds on earlier topics naturally
#
# 4. **✅ Personalized Responses**
#    - Remembers user preferences and goals
#    - Adapts follow-up questions accordingly
#
# 5. **✅ Zero Configuration**
#    - ChromaDB embedded storage
#    - Works immediately, no setup required
#
# ### The Agent's Memory Workflow:
#
# ```
# User Input → Search Memories → Build Context → Generate Response → Store Interaction
#      ↑                                                                      ↓
#      └──────────────────── Memory Persists ──────────────────────────────┘
# ```

# %% [markdown]
# ## 🚀 Next Steps
#
# ### Experiment Further:
#
# 1. **Test Memory Persistence**
#    - Close this notebook and reopen it
#    - The agent should still remember your conversations!
#
# 2. **Try Different Topics**
#    - Talk about hobbies, projects, goals
#    - See how the agent builds a profile of you
#
# 3. **Explore Memory Search**
#    - Search for different topics
#    - Notice how semantic search finds related concepts
#
# 4. **Build Your Own Agent**
#    - Copy the agent pattern
#    - Customize for your use case
#    - Add domain-specific knowledge
#
# ### Key Praval Memory APIs:
#
# ```python
# # Enable memory in agent
# @agent("name", memory=True)
#
# # Store a memory
# agent.remember("important fact", importance=0.8)
#
# # Search memories
# results = agent.recall("query", limit=5)
#
# # Get specific memory
# memory = agent.recall_by_id("id")
#
# # Get conversation history
# context = agent.get_conversation_context(turns=10)
# ```
#
# ### Learn More:
#
# - 📖 [Memory System Documentation](../docs/memory-system.md)
# - 🎯 [Multi-Agent Memory Example](../examples/005_memory_enabled_agents.py)
# - 🌐 [Praval GitHub](https://github.com/aiexplorations/praval)
